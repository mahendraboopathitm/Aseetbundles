# %%
data=[("101","boopathi","it","50000"),
      ("102","kavin","hr","600000"),
       ("103","subash","finance","700000"),
       ("104","santhosh","it","800000"),
       ("105","suresh","hr","900000"),
       ("106","santhosh","finance","1000000"),
       ("107","suresh","it","1100000"),
       ("108","santhosh","hr","1200000"),
       ("102","kavin","hr","600000")
      ]

schema=["id","name","department","salary"]

df2=spark.createDataFrame(data,schema)
df2.show()
